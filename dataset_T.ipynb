# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the data
df1_exercises = pd.read_csv('data/datasets/exercises.csv', encoding='latin1')
df2_exercises = pd.read_csv('data/datasets/megaGymDataset.csv', encoding='latin1')

# %% [markdown]
# # tratar dataset df2_exercises

# %%
df2_exercises
# Out:
#       Unnamed: 0                                           Title  \
# 0              0                          Partner plank band row
# 1              1                    Banded crunch isometric hold
# 2              2                           FYR Banded Plank Jack
# 3              3                                   Banded crunch
# 4              4                                          Crunch
# ...          ...                                             ...
# 2913        2913                            EZ-bar skullcrusher-
# 2914        2914  Lying Close-Grip Barbell Triceps Press To Chin
# 2915        2915          EZ-Bar Skullcrusher - Gethin Variation
# 2916        2916                                TBS Skullcrusher
# 2917        2917                     30 Arms EZ-Bar Skullcrusher
#
#                                                    Desc      Type    BodyPart  \
# 0     The partner plank band row is an abdominal exe...  Strength  Abdominals
# ...

# %%
df2_exercises = df2_exercises.loc[df2_exercises['Level'] == 'Beginner']

# %%
df2_exercises
# Out:
#       Unnamed: 0                                           Title  \
# 11            11                          Bench barbell roll-out
# 12            12                               Barbell Side Bend
# 20            20                    Advanced Kettlebell Windmill
# 22            22                Kettlebell Pass Between The Legs
# 40            40                           Dumbbell spell caster
# ...          ...                                             ...
# 2841        2841                     Low Cable Triceps Extension
# 2889        2889                Standing Towel Triceps Extension
# 2892        2892                                Overhead Triceps
# 2910        2910                              Supine Chest Throw
# 2914        2914  Lying Close-Grip Barbell Triceps Press To Chin
#
#                                                    Desc         Type  \
# 11    The bench barbell roll-out is a challenging ex...     Strength
# ...

# %%
count_nan = df2_exercises['Desc'].isna().sum()
print('Count of NaN:', count_nan)
# Out:
# Count of NaN: 351

# %%
df2_exercises.to_csv('df_exer.csv', index=False)

# %% [markdown]
# # tartar do megaGymDataset

# %%
df1_exercises
# Out:
#         bodyPart    equipment                                         gifUrl  \
# 0          waist  body weight  https://v2.exercisedb.io/image/MOnK4iG0MEt9h8
# 1          waist  body weight  https://v2.exercisedb.io/image/PERWLDGUxVbpHS
# 2          waist  body weight  https://v2.exercisedb.io/image/PLr4yo3j-f1amp
# 3     upper legs  body weight  https://v2.exercisedb.io/image/XPQwM7HECjgNFE
# 4          waist  body weight  https://v2.exercisedb.io/image/5nYph4eUGNiEdf
# ...          ...          ...                                            ...
# 1319       chest  body weight  https://v2.exercisedb.io/image/XQn4pU9HRquS2b
# 1320       waist  body weight  https://v2.exercisedb.io/image/ZLPKUAaiObH-2X
# 1321  upper legs  body weight  https://v2.exercisedb.io/image/3A5fPe5oCr2EwN
# 1322  lower arms  body weight  https://v2.exercisedb.io/image/o8lN2wxaJZIzlF
# 1323  lower arms     weighted  https://v2.exercisedb.io/image/bpHngD4xNKxD6u
#
# ...

# %%
df1_exercises.drop('gifUrl', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df1_exercises.drop('gifUrl', axis=1, inplace=True)
#       2 df1_exercises.drop('id', axis=1, inplace=True)
#
# File ~\.conda\envs\myenv\lib\site-packages\pandas\core\frame.py:5568, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5420 def drop(
#    5421     self,
#    5422     labels: IndexLabel | None = None,
#    (...)
#    5429     errors: IgnoreRaise = "raise",
#    5430 ) -> DataFrame | None:
#    5431     """
#    5432     Drop specified labels from rows or columns.
#    5433
#    (...)
#    5566             weight  1.0     0.8
#    5567     """
# -> 5568     return super().drop(
#    5569         labels=labels,
#    5570         axis=axis,
#    5571         index=index,
#    5572         columns=columns,
#    5573         level=level,
# ...

# %%
df1_exercises
# Out:
#         bodyPart    equipment    id  \
# 0          waist  body weight     1
# 1          waist  body weight     2
# 2          waist  body weight     3
# 3     upper legs  body weight  1512
# 4          waist  body weight     6
# ...          ...          ...   ...
# 1319       chest  body weight  2363
# 1320       waist  body weight   858
# 1321  upper legs  body weight  1604
# 1322  lower arms  body weight  1428
# 1323  lower arms     weighted   859
#
#                                            name      target  \
# 0                                    3/4 sit-up         abs
# 1                                45Â° side bend         abs
# 2                                      air bike         abs
# 3                       all fours squad stretch       quads
# 4                       alternate heel touchers         abs
# ...                                         ...         ...
# 1319  wide-grip chest dip on high parallel bars   pectorals
# ...

# %%
df1_exercises.drop('id', axis=1, inplace=True)

# %%
df1_exercises
# Out:
#         bodyPart    equipment                                       name  \
# 0          waist  body weight                                 3/4 sit-up
# 1          waist  body weight                             45Â° side bend
# 2          waist  body weight                                   air bike
# 3     upper legs  body weight                    all fours squad stretch
# 4          waist  body weight                    alternate heel touchers
# ...          ...          ...                                        ...
# 1319       chest  body weight  wide-grip chest dip on high parallel bars
# 1320       waist  body weight                               wind sprints
# 1321  upper legs  body weight                     world greatest stretch
# 1322  lower arms  body weight                              wrist circles
# 1323  lower arms     weighted                             wrist rollerer
#
#           target secondaryMuscles/0 secondaryMuscles/1  \
# ...

# %%
sns.heatmap(df1_exercises.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
to_drop = ['secondaryMuscles/1', 'instructions/5','instructions/6','secondaryMuscles/2','instructions/7',
           'secondaryMuscles/3', 'instructions/8', 'secondaryMuscles/4', 'instructions/9', 'secondaryMuscles/5','instructions/10']
df1_exercises = df1_exercises.drop(to_drop, axis=1)
df1_exercises
# Out:
#         bodyPart    equipment                                       name  \
# 0          waist  body weight                                 3/4 sit-up
# 1          waist  body weight                             45Â° side bend
# 2          waist  body weight                                   air bike
# 3     upper legs  body weight                    all fours squad stretch
# 4          waist  body weight                    alternate heel touchers
# ...          ...          ...                                        ...
# 1319       chest  body weight  wide-grip chest dip on high parallel bars
# 1320       waist  body weight                               wind sprints
# 1321  upper legs  body weight                     world greatest stretch
# 1322  lower arms  body weight                              wrist circles
# 1323  lower arms     weighted                             wrist rollerer
#
#           target secondaryMuscles/0  \
# 0            abs        hip flexors
# ...

# %%
sns.heatmap(df1_exercises.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
df1_exercises.to_csv('df_noLevel.csv', index=False)
